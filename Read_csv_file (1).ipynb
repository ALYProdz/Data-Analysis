# %%
import pandas as pd

# %%
#Read a csv file
df = pd.read_csv("./Downloads/Coursera Data Analysis/Automobile+%281%29.csv")

# %%
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
#Read Json file
jd = pd.read_json("./Downloads/file.json")

# %%
jd
# Out:
#                         name        phoneNumber  \
# 0           Buford Rosenbaum     1-616-394-1410
# 1          Linwood Lemke DVM     1-805-725-1546
# 2             Raheem Tillman    +1-339-246-4369
# 3             Lester Murazik       241.809.4749
# 4               Maida Zulauf  +1 (271) 507-2009
# 5        Ms. Ellen Johnson I       229-855-3682
# 6        Dr. Alessia Jenkins     1-334-832-2648
# 7                 Mose Hintz       563-733-2657
# 8           Eladio Buckridge       381-514-0015
# 9   Prof. Macie Armstrong IV    +1-865-840-3309
# 10               Myrl Crooks       837.772.8590
# 11         Morton Herzog III       412.313.1047
# 12        Theodore Gutkowski  +1 (730) 866-9240
# 13             Retta Schmidt       921.467.8555
# 14          Gabrielle Wunsch    +1-306-685-3510
# 15               Karli Jones     (491) 604-6709
# 16   Prof. Adrianna Waters I       919.239.1976
# 17         Anjali Erdman DVM       232.865.4880
# ...
